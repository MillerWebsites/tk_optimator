# %%
from typing import List
import random
 

VOWELS = ["ee", "oo", "aa", "eo", "ai", "uo", "uuu", "ooaa", "ru"]
CONSONANTS = ["t", "k", "p", "b", "d", "g", "m", "n", "h", "w", "y", "r", "s", "l"]
VOWEL = ["a", "e", "i", "o", "u", "y", "w"]

CONSONANT_COMBINATIONS = [
    "ch", "st", "sh", "th", "ph", "wh", "ch", "sh", "th", "ph", "wh", "ch", "sh", "th", "ph", "wh"
]

def generate_section(length: int) -> str:
    """Generates a section of the melody."""
    section = []
    for _ in range(length):
        vowel_combo = random.choice(VOWELS)
        if vowel_combo in ("ai", "eo", "ru"):
            vowel_combo += random.choice(VOWEL)
        consonant = random.choice(CONSONANT_COMBINATIONS) + random.choice(VOWEL)
        if consonant in ("h", "l"):
            consonant += random.choice(VOWEL)
            consonant += random.choice(CONSONANTS)
        suffix = random.choice(VOWEL) + " " + random.choice(CONSONANTS) + random.choice(VOWEL)
        section.append(consonant+vowel_combo + " "+ suffix)
    return " ".join(section)



def generate_variation() -> str:
    """Generates a half-length section."""
    section = []
    for _ in range(10):
        vowel_combo = random.choice(VOWELS)
        if vowel_combo in ("ai", "eo", "ru"):
            vowel_combo += random.choice(CONSONANTS) + " " +  random.choice(VOWEL)
        consonant = random.choice(CONSONANTS)
        if consonant == "h":
            consonant += random.choice(VOWEL)
            consonant += random.choice(CONSONANTS)
        elif consonant == "w":
            consonant += random.choice(VOWEL)
        suffix = random.choice(VOWEL) + " " + random.choice(CONSONANTS) + random.choice(VOWEL)
        section.append(consonant+vowel_combo+suffix)
    return " ".join(section)


def halve_length(melody: List[str]) -> List[str]:
    """Halves the length of the melody."""
    return [melody[i] for i in range(len(melody)) if i % 2 == 0]

def remove_letters(melody: List[str]) -> List[str]:
    """Removes the letters from the melody."""
    return [melody[i] for i in range(len(melody)) if not i % 2 == 0]


def generate_melody() -> List[str]:
    """Generates the melody."""
    return [generate_section(10) for _ in range(10)]

def transpose_letters(melody: List[str]) -> List[str]:
    """Transposes the letters in the melody."""
    return [melody[i].upper() for i in range(len(melody))]

def main() -> None:
    """Main function."""
    melody = generate_melody()      
    transposed_melody = transpose_letters(melody)
    halved_melody = halve_length(transposed_melody)
    removed_melody = remove_letters(melody)
    removed_halved_melody = remove_letters(halved_melody)
    removed_encore = remove_letters(generate_melody())

    final_melody = f"{removed_melody}, {removed_halved_melody}, {removed_encore}"


    print(melody)
    #print(transposed_melody)
    #print(halved_melody)
    ##print(removed_halved_melody)
    #print(final_melody)


if __name__ == "__main__":
    main()
# Out:
# ['whirui a ne phauuu y la stouuu y si thiaa u na phuee o rw steaa y ko phieoe o by phaee u wu phiooaa u ko whiaie w ky', 'stwee o yi wheooaa i po chwaa e na shuaie a gy wharue y pa thuaia a ww shiooaa w yi shwuuu i di chaee a ru whuaio i dy', 'whwoo o ti whwooaa w mi phoeoy o gi whyaie o du thooo y ky pheeow i dy chyoo a ye shwoo e by phuooaa y se chwaa w lu', 'chiruy a sw steuuu u yw wheeoy y yu stirua w bi phaooaa e sw chuoo o hi whiuuu a he stieou u ny whyooaa w tw phiuo w kw', 'whoooaa w po shauuu e ny whoruy y po phwoo a pu sheuo u sa shyooaa a ne shuooaa u da whaeoo w ke shaooaa i ry pheooaa i pu', 'stoaa e kw shyooaa e te phuaa u be stwee w ra whyaa w ly whiaa u hw whueoe e wi chiruo e pi whuooaa u po stuooaa o hy', 'chiruw w ge whouuu u na pheuuu e rw pharui o we chuooaa w yo theee u du thiaiw u bw whoooaa e ke chyaa u mw shweoa a wi', 'thiee y bi phyoo y yy shuee u le sheee w lu phuooaa a dy whiaa a bw chioo o bi phwuo o ga shouo w gi wheee u ho', 'phouuu y ye whiaiy i yi sh
# ...

# %% [markdown]
# #Import Google-GenerativeAI and set up a conversational chat with Gemini Pro 1.5 latest
# def

# %% [markdown]
# Be A Master of Understanding
#
# Why is it that some python classess don't utilize
# def _init_ self ?
#
# In Python, the __init__ method is a special method called a constructor. It is automatically invoked when a new instance (object) of a class is created, and it is used to initialize the object’s attributes. However, not all Python classes need to use the __init__ method. Here are some reasons why a class might not utilize __init__:
#
# 1. Simple Classes Without Initialization Needs
#
# No Attributes to Initialize: If a class does not need to initialize any attributes or perform any setup when an object is created, it can omit the __init__ method.
#
# Example:
# Python
# class SimpleClass:
#     def greet(self): print("Hello, World!") obj = SimpleClass() obj.greet()
#
# 2. Using Class Methods or Static Methods
#
# Class Methods: These methods are bound to the class and not the instance. They can be used to create alternative constructors.
#
# Static Methods: These methods do not access or modify the class or instance state.
#
# Example:
# Python
# class AlternativeConstructor: @classmethod
# def create(cls): instance = cls() # Perform some setup return instance @staticmethod
# def utility_method(): print("This is a static method.") obj = AlternativeConstructor.create() AlternativeConstructor.utility_method()
#
# 3. Inheritance and Overriding
#
# Inherited Initialization: In some cases, a subclass might rely on the parent class’s __init__ method and not need its own.
#
# Example:
# Python
# class Parent:
#     def __init__(self, value): self.value = value class Child(Parent): pass obj = Child(10) print(obj.value) # Output: 10
#
# 4. Data Classes
#
# Automatic Initialization: Python’s dataclasses module can automatically generate the __init__ method based on class annotations.
#
# Example:
# Pythonfrom dataclasses import dataclass @dataclass class DataClassExample:
#  name: str age: int obj = DataClassExample(name="Alice", age=30) print(obj.name, obj.age) # Output: Alice 30
#
# 5. Metaclasses and Custom Object Creation
#
# Custom Object Creation: Advanced use cases might involve metaclasses or custom object creation methods that do not require __init__.
#
# Example:
# Python
# class Meta(type):
#     def __call__(cls, *args, **kwargs): instance = super().__call__(*args, **kwargs) # Custom initialization return instance class CustomClass(metaclass=Meta): pass obj = CustomClass()
#
# What are some common use cases for __init__ in Python classes?
#
# The __init__ method in Python classes is used for a variety of purposes, primarily to initialize the attributes of an object when it is created. Here are some common use cases:
#
# 1. Initializing Instance Variables
#
# Purpose: To set up initial values for the attributes of an object.
#
# Example:
# Python
# class Person:
#     def __init__(self, name, age): self.name = name self.age = age person = Person("Alice", 30) print(person.name, person.age) # Output: Alice 30
#
# 2. Setting
# Default Values
#
# Purpose: To provide
# default values for attributes if no specific values are provided.
#
# Example:
# Python
# class Car:
#     def __init__(self, make, model, year=2020): self.make = make self.model = model self.year = year car = Car("Toyota", "Corolla") print(car.year) # Output: 2020
#
# 3. Validating Input Data
#
# Purpose: To validate the input data and ensure it meets certain criteria.
#
# Example:
# Python
# class Rectangle:
#     def __init__(self, width, height): if width <= 0 or height <= 0: raise ValueError("Width and height must be positive numbers.") self.width = width self.height = height rect = Rectangle(10, 5)
#
# 4. Resource Allocation
#
# Purpose: To allocate resources such as opening files or establishing database connections.
#
# Example:
# Python
# class FileHandler:
#     def __init__(self, filename): self.file = open(filename, 'r')
# def read_file(self): return self.file.read()
# def __del__(self): self.file.close() handler = FileHandler("example.txt") print(handler.read_file())
#
# 5. Dependency Injection
#
# Purpose: To inject dependencies or other objects that the class relies on.
#
# Example:
# Python
# class Service:
#     def __init__(self, repository): self.repository = repository
# def get_data(self): return self.repository.fetch_data() class Repository:
#     def fetch_data(self): return "Data from repository" repo = Repository() service = Service(repo) print(service.get_data()) # Output: Data from repository
#
# 6. Setting Up Complex Objects
#
# Purpose: To set up complex objects that require multiple steps or configurations.
#
# Example:
# Python
# class ComplexObject:
#     def __init__(self, part1, part2): self.part1 = part1 self.part2 = part2 self.setup()
# def setup(self): # Complex setup logic self.combined = f"{self.part1}-{self.part2}" obj = ComplexObject("PartA", "PartB") print(obj.combined) # Output: PartA-PartB
#
# 7. Logging and Debugging
#
# Purpose: To log or debug information during object creation.
#
# Example:
# Pythonimport logging class Logger:
# def __init__(self, name): self.logger = logging.getLogger(name) self.logger.setLevel(logging.DEBUG) handler = logging.StreamHandler() handler.setLevel(logging.DEBUG) self.logger.addHandler(handler)
# def log(self, message): self.logger.debug(message) logger = Logger("MyLogger") logger.log("This is a debug message.")
#
# These use cases illustrate the versatility of the __init__ method in setting up and managing the state and behavior of objects in Python.
#
# What are some best practices for using __init__ effectively?
#
# Using the __init__ method effectively in Python classes is crucial for creating well-structured and maintainable code. Here are some best practices to follow:
#
# 1. Initialize All Necessary Attributes
#
# Purpose: Ensure that all attributes needed for the class are initialized within the __init__ method.
#
# Example:
# Python
# class Person:
#     def __init__(self, name, age): self.name = name self.age = age
#
# 2. Avoid Using Mutable
# Default Arguments
#
# Purpose: Prevent unexpected behavior by avoiding mutable
# default arguments like lists or dictionaries.
#
# Example:
# Python
# class MyClass:
#     def __init__(self, my_list=None): if my_list is None: my_list = [] self.my_list = my_list
#
# 3. Use Keyword-Only Arguments
#
# Purpose: Improve code readability and prevent errors by using keyword-only arguments.
#
# Example:
# Python
# class Car:
#     def __init__(self, make, model, *, year=2020): self.make = make self.model = model self.year = year
#
# 4. Keep Initialization Simple
#
# Purpose: Avoid performing complex computations or time-consuming tasks within the __init__ method.
#
# Example:
# Python
# class DataProcessor:
#     def __init__(self, data): self.data = data self.processed_data = self.process_data()
# def process_data(self): # Complex processing logic return processed_data
#
# 5. Use Descriptive Parameter Names
#
# Purpose: Make the code more readable and self-explanatory by using descriptive parameter names.
#
# Example:
# Python
# class Book:
#     def __init__(self, title, author, publication_year): self.title = title self.author = author self.publication_year = publication_year
#
# 6. Document the __init__ Method
#
# Purpose: Provide clear documentation for the __init__ method to explain the purpose of each parameter.
#
# Example:
# Python
# class Employee:
#     def __init__(self, name, position, salary): """ Initialize an Employee object. :param name: The name of the employee. :param position: The position of the employee. :param salary: The salary of the employee. """ self.name = name self.position = position self.salary = salary
#
# 7. Use super() for Inheritance
#
# Purpose: Ensure proper initialization of parent classes when using inheritance.
#
# Example:
# Python
# class Animal:
# def __init__(self, species):
# self.species = species
#
# class Dog(Animal):
# def __init__(self, name, breed):
#     super().__init__(species="Dog")
#     self.name = name
#     self.breed = breed
#
# 8. Avoid Side Effects
#
# Purpose: Ensure that the __init__ method does not have side effects that could affect other parts of the program.
#
# Example:
# Python
# class Logger:
# def __init__(self, log_file):
#     self.log_file = log_file # Avoid opening the file here; do it in a separate method
#
# 9. Use Properties for Complex Initialization
#
# Purpose: Use properties to handle complex initialization logic that should not be in the __init__ method.
#
# Example:
# Python
# class Circle:
# def __init__(self, radius):
# self.radius = radius
#
# @property
# def area(self):
#     return 3.14159 * self.radius ** 2
#
# 10. Prefer Composition Over Inheritance
#
# Purpose: Use composition to include functionality from other classes rather than relying solely on inheritance.
#
# Example:
# Python
# class Engine:
#     def start(self): print("Engine started") class Car:
#     def __init__(self, make, model): self.make = make self.model = model self.engine = Engine()
# def start(self): self.engine.start()
#
# By following these best practices, you can ensure that your __init__ methods are clear, efficient, and maintainable.
