# %%
import requests
from   bs4 import BeautifulSoup
import html2text
import random
from search_manager import WebContentExtractor

#create instance of WebContentExtractor
web_content_extractor = WebContentExtractor()

#Search using requests and the url: https://search.foia.gov/search?utf8=%E2%9C%93&m=true&affiliate=foia.gov&query={query variable goes here and replace spaces with "+"}
def foia_search(query):
    url = f"https://search.foia.gov/search?utf8=%E2%9C%93&m=true&affiliate=foia.gov&query={query.replace(' ', '+')}"
    headers = {
        'User-Agent': random.choice(WebContentExtractor.USER_AGENTS),
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Cache-Control': 'max-age=0',
        'DNT': '1',
    }
    response = requests.get(url, headers=headers, timeout=WebContentExtractor.TIMEOUT)
    response.raise_for_status()
    html_content = response.content
    # Process the HTML content as needed, extract links from HTML content into iterable list
    soup = BeautifulSoup(html_content, 'html.parser')
    links = [link.get('href') for link in soup.find_all('a')]
    content = []
    for link in links:
        contents = WebContentExtractor.extract_content(link)
        content.append(contents)
    return content
query = "Kuwait Oil Files"
html_content = foia_search(query)
content = html2text.html2text(html_content)
print(content)
# Out:
# Skip to main content
#
# Menu Browse site
#
# #
# [![FOIA.gov](https://d3qcdigd1fhos0.cloudfront.net/production/site/1687/mobile_logo/1640634388/original/foia-
# header.jpg?1640634388)](https://www.foia.gov)
#
# ## Menu
#
#   * Browse site
#     * [Home](http://www.foia.gov/)
#     * [About](http://www.foia.gov/about.html)
#     * [Data](http://www.foia.gov/data.html)
#     * [Report](http://www.foia.gov/reports.html)
#     * [FAQs](http://www.foia.gov/faq.html)
#     * [FOIA Contacts](https://www.foia.gov/#agency-search)
#
# Enter your search term
#
# Clear
#
# ## Search results
#
# ### Powered by Bing
#
# ####  [**Kuwait Oil Fires** \-
# NASA](https://visibleearth.nasa.gov/images/78594/kuwait-oil-fires)
#
# visibleearth.nasa.gov/images/78594/kuwait-oil-fires
#
# As Iraqi forces withdrew from **Kuwait** , they set fire to more 650 **oil**
# wells and damaged roughly 75 more, which then spewed crude **oil** across the
# desert ...
#
# ####  [**Oil** Well **Fires** during Gulf War - **Public
# Health**](https://www.publichealth.va.gov/exposures/gulfwar/sources/oil-well-
# fires.asp)
#
# www.publichealth.va.gov/exposures/gulfwar/sources/oil-well-fires.asp
#
# Exposure during the Gulf War. Between February to November 1991, Iraqi armed
# forces ignited **oil** well **fires** , producing dense clouds of soot, liquid
# ...
#
# ####  [**Kuwait** **oil** **fires** : air quality data and
# reports](https://repository.library.noaa.gov/view/noaa/16277)
#
# repository.library.noaa.gov/view/noaa/16277
#
# Gulf Program Office, Office of Chief Scientist, National Oceanic and
# Atmospheric Administration. "The reports in this collection are a cross
# section ...
#
# ####  [Health effects of the 1991 **Kuwait** **oil** **fires** : a survey of
# US ... - PubMed](https://pubmed.ncbi.nlm.nih.gov/10390693/)
#
# pubmed.ncbi.nlm.nih.gov/10390693/
#
# The burning of **oil** wells in **Kuwait** in 1991 discharged a high volume of
# potentially toxic pollutants into the air. To determine whether there were ...
#
# ####  [Landsat Image Gallery - **Kuwait** **Oil** **Fires** \-
# NASA](https://landsat.visibleearth.nasa.gov/view.php?id=78594)
#
# landsat.visibleearth.nasa.gov/view.php?id=78594
#
# Data Date: February 22, 2001. Visualization Date: July 19, 2012. In 1991,
# Landsat captured the devastating environmental consequences of war. As Iraqi
# ...
#
# ####  [NASA SVS | **Kuwait Fires with Dates**](https://svs.gsfc.nasa.gov/2736)
#
# svs.gsfc.nasa.gov/2736
#
# Viewing the **oil** **fires** during the Gulf War in 1991. || Scientific
# Visualization Studio. Galleries; Help; Search 2715: **Kuwait** **Fires** ... A
# look back at ...
#
# ####  [PDF] [**Air Pollutant Exposures due to the** **Kuwait** **Oil**
# **Fires**](https://www.arl.noaa.gov/documents/reports/pergulf.pdf)
#
# www.arl.noaa.gov/documents/reports/pergulf.pdf
#
# An Evaluation of **Air Pollutant Exposures due to the** 1991 **Kuwait**
# **Oil** **Fires** using a Lagrangian Model. Roland R. Draxler, Jeffery T.
# McQueen, Barbara ...
#
# ####  [The **Kuwait** **oil** **fires** as seen by Landsat - NASA Technical
# Reports Server ...](https://ntrs.nasa.gov/citations/19920072842)
#
# ntrs.nasa.gov/citations/19920072842
#
# The **Kuwait** **oil** **fires** as seen by Landsat A mosaic of two Landsat
# thematic mapper images acquired May 30, 1991, reveals a dark smoke plume 30-60
# km wide ...
#
# ####  [NASA SVS | **Kuwait Fires**](https://svs.gsfc.nasa.gov/2715)
#
# svs.gsfc.nasa.gov/2715
#
# Viewing the **oil** **fires** during the Gulf War in 1991. || A look back at
# the **Kuwait fires** from the Gulf War. || a002715.00005_print.png (720x480)
# [554.8 ...
#
# ####  [Exposures to the **Kuwait** **oil** **fires** and their association
# with asthma and ...](https://ehp.niehs.nih.gov/doi/pdf/10.1289/ehp.021101141)
#
# ehp.niehs.nih.gov/doi/pdf/10.1289/ehp.021101141
#
# Environmental Health Perspectives • VOLUME 110 | NUMBER 11 | November 2002 1141 Exposures to the **Kuwait** **Oil** **Fires** and Their Association with Asthma ...
#
# ####  [**kuwait** **oil** **fires** : Topics by
# Science.gov](https://www.science.gov/topicpages/k/kuwait+oil+fires)
#
# www.science.gov/topicpages/k/kuwait+oil+fires
#
# **Kuwait** **Oil** **Fires** , **Kuwait**. NASA Technical Reports Server
# (NTRS) 1991-01-01. The number of **oil** well **fires** from the **Kuwait**
# **Oil** Fields (29.5N, 48.0E) set ...
#
# ####  [TAB **C – Fighting the Oil Well
# Fires**](https://www.gulflink.osd.mil/owf_ii/owf_ii_tabc.htm)
#
# www.gulflink.osd.mil/owf_ii/owf_ii_tabc.htm
#
# 750 Wells. The **oil** well fire fighters were quick to develop and implement
# innovative fire-fighting techniques. In early April 1991, the first **fires**
# ...
#
# ####  [**Kuwait** **oil** **fires** \- Compositions of source smoke - NASA
# Technical ...](https://ntrs.nasa.gov/search.jsp?R=19920072835)
#
# ntrs.nasa.gov/search.jsp?R=19920072835
#
# **Kuwait** **oil** **fires** \- Compositions of source smoke While the
# **Kuwait** **oil** -fire smoke plumes manifested a pronounced impact on solar
# radiation in the Gulf ...
#
# ####  [Section 4 - Military Health
# System](https://gulflink.health.mil/oil_well_fires/oil_well_fires_sec04.htm)
#
# gulflink.health.mil/oil_well_fires/oil_well_fires_sec04.htm
#
# One of the most dramatic consequences of the **oil** field **fires** was the
# development of smoke plumes that rose into the atmosphere. The pillar-like
# plumes ...
#
# ####  [**Kuwait Oil Fires: Interagency Interim Report** \- US
# EPA](https://nepis.epa.gov/Exe/ZyPURL.cgi?Dockey=90050O00.TXT)
#
# nepis.epa.gov/Exe/ZyPURL.cgi?Dockey=90050O00.TXT
#
# **Kuwait** **Oil** I BAHRAIN Jiiteragency Report April 3, 1991 \ / 160/ 1991.3
# \\. ------- **KUWAIT OIL FIRES INTERAGENCY INTERIM REPORT** I. SUMMARY h V
# More than ...
#
# ####  [The **Kuwait** **Oil** Fire Health Risk Assessment Biological ... -
# PubMed](https://pubmed.ncbi.nlm.nih.gov/21916331/)
#
# pubmed.ncbi.nlm.nih.gov/21916331/
#
# Abstract. An important environmental concern during the first Gulf War
# (Operation Desert Storm) was assessing exposures and potential health effects
# ...
#
# ####  [1991 **Kuwait** **Oil** **Fires** | U.S. Geological Survey - **USGS.gov**](https://www.usgs.gov/media/images/1991-kuwait-oil-fires)
#
# www.usgs.gov/media/images/1991-kuwait-oil-fires
#
# 1991 **Kuwait** **Oil** **Fires** By EROS History Project 1991 (approx.)
# Original Thumbnail Medium. Detailed Description. 1991 **Kuwait** **Oil**
# **Fires** \- EROS History ...
#
# ####  [**Oil** Well **Fires** \- **War Related Illness and Injury Study
# Center**](https://www.warrelatedillness.va.gov/education/exposures/oil-well-
# fires.asp)
#
# www.warrelatedillness.va.gov/education/exposures/oil-well-fires.asp
#
# **Oil** well fire smoke often contains soot particles made of carbon from
# burning **oil**. Other particles may be mixed in the smoke such as sand, dust,
# and ...
#
# ####  [Landsat Image Gallery - **Kuwait** **Oil**
# Fire](https://landsat.visibleearth.nasa.gov/view.php?id=39587)
#
# landsat.visibleearth.nasa.gov/view.php?id=39587
#
# The Iraqi soldiers set fire to Kuwaiti **oil** fields during their retreat.
# The **oil** **fires** , as seen here in this February 22, 1991 Landsat 5
# image, are ...
#
# ####  [Exposures to the **Kuwait** **oil** **fires** and their association
# with asthma and ...](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1241071/)
#
# www.ncbi.nlm.nih.gov/pmc/articles/PMC1241071/
#
# Approximately 94% of the study cohort were still in the gulf theater during
# the time of the **oil** -well **fires** , and 21% remained there more than 100
# days ...
#
# Powered by Bing
#
# ### Pagination
#
# « PreviousPage 1[Next
# »](/search?affiliate=foia.gov&m=true&page=2&query=Kuwait+Oil+Files&utf8=%E2%9C%93)
#
# ## Footer links
#
#   * [Accessibility](https://www.justice.gov/accessibility/accessibility-information)
#   * [Privacy Policy](https://www.justice.gov/doj/privacy-policy)
#   * [Policies & Disclaimers](https://www.justice.gov/legalpolicies)
#   * [Information Quality](https://www.justice.gov/iqpr/information-quality)
#   * [Developer Resources & FOIA API](https://www.foia.gov/developer/)
#   * [Justice.gov](http://www.justice.gov/)
#   * [USA.gov](http://www.usa.gov/)
